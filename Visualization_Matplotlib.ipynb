# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
year = [2019, 2020, 2021]
growth= [10, 19, 38]

plt.figure(figsize=(7,3))
plt.plot(year, growth)
plt.xlabel('Year')
plt.ylabel('Growth')
plt.title("Growth over Year")
plt.show()
